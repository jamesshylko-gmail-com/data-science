# %% [markdown]
# ### Цены на жилье в Бостоне — передовые методы регрессионного анализа
#
# [https://www.kaggle.com/datasets/fedesoriano/the-boston-houseprice-data]
#
# Выходная переменная:
# 1) MEDV: Медианная стоимость домов, находящихся в собственности владельцев, в тысячах долларов [k$]

# %%
import pandas as pd

from private import utils
from public import analyzer

data_frame : pd.DataFrame = utils.prepare_boston_data()
analyzer.report(
    data_frame,
    [
        analyzer.dataset_stats_info,
        analyzer.duplicates_info,
        analyzer.missing_value_info,
        analyzer.not_numeric_columns_info,
        analyzer.anomalies_info
    ] 
)
# Out:
# total
# 	506
#
# head
# 	      CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 	0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 	1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 	2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 	3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 	4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
# 	   PTRATIO       B  LSTAT  MEDV
# 	0     15.3  396.90   4.98  24.0
# 	1     17.8  396.90   9.14  21.6
# 	2     17.8  392.83   4.03  34.7
# 	3     18.7  394.63   2.94  33.4
# 	4     18.7  396.90   5.33  36.2
#
# total duplicates
# 	0
#
# duplicates
# 	None
#
# columns with missed values
# 	Series([], dtype: int64)
#
# columns with not numeric types
#
#
# anomalies
# 	Not implemented yet

# %%
from public.model_for_linear_regresssion import LinearRegressionModel

model: LinearRegressionModel = (
        LinearRegressionModel(df=data_frame, target_column="MEDV", test_size=0.3)  # set datadrame
        .preprocessing(  # transmrm dataframe based on analizer info
            {
                # "standard_scaller": {},
            }
        )
        .training()  # trainig
        .predict()  # predicttion based on test data
        .evaluate()  # evaluate model presicion
)
model.report()
model.draw()
# Out:
# preprocessing took 0.000 seconds
# training took 0.002 seconds
# predict took 0.003 seconds
# evaluate took 0.000 seconds
# Коэффициенты линейной регрессии:
# 	[ 1.29693856  0.01469497  0.04050457  0.79060732 -9.12933243  9.24839787
#  -0.0451214  -0.91395374  0.14079658 -0.01477291 -0.63369567  0.01577172
#  -0.09514128]
# Intercept:
# 	-13.672146552166751
# Среднеквадратичная ошибка:
# 	nan
# Коэффициент детерминации R^2:
# 	-7.243407441978055
# report took 0.002 seconds
