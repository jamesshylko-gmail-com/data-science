# %% [markdown]
# ### 6. Создайте два множества из 4 разных чисел каждое, найдите их пересечение и выведите на экран.
#
# P.S. Сложность: временная O(min(m,n)), по памяти - O(min(m,n))

# %%
set_1 = {1, 2, 3, 4}
set_2 = {3, 4, 5, 6}

print(set_1 & set_2)
# Out:
# {3, 4}
