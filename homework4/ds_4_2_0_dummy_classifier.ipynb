# %% [markdown]
# ### Dummy Classifier
# 1) Полученные характеристики слишком далеки от результатов алгоритмов. Поэтому на графиках в отчете их не выводим. Это позволит нам в точете приблизить шкалу по "y" хотя бы к (0.6, 1), чтобы получше рассмотреть различия

# %%
from private.utils import get_reduced_mnist_data, memory_check
from public.classification_utils import DUMMY
from public.models import ClassificationProcessor

with memory_check():
    df = get_reduced_mnist_data()
    processor = ClassificationProcessor(df, "label")   
    processor.calculate({
        DUMMY : {},
    })
    processor.report(DUMMY, matrix=True)
    processor.pick_model(DUMMY)
# Out:
# c:\Users\User\PythonProject\data-science\homework4\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\User\PythonProject\data-science\homework4\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ...
